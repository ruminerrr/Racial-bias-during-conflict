# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import hddm
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/parallel.py:12: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   warn("The `IPython.parallel` package has been deprecated since IPython 4.0. "

# %%
# Load data
data = hddm.load_csv('eeg_ddm_StimAllElec_new.csv')
data.rt = data.rt/1000
data.response = 1-data.response
data = hddm.utils.flip_errors(data)
data = data[data['type']=='pain']
data = data[data['race']=='Asian']
data
# Out:
#        subj_idx outSold    stim stimulus  type  response     rt  gender  \
# 8            15     low  female     face  pain         1  2.242  female
# 9            15     low  female     face  pain         1  1.941  female
# 10           15     low  female     face  pain         1  2.242  female
# 11           15     low  female     face  pain         1  2.142  female
# 12           15     low    male     face  pain         1  1.836  female
# ...         ...     ...     ...      ...   ...       ...    ...     ...
# 14941        94    high  female     face  pain         0 -1.858  female
# 14942        94    high    male     face  pain         0 -2.258  female
# 14943        94    high    male     face  pain         0 -2.359  female
# 14944        94    high    male     face  pain         0 -1.958  female
# 14945        94    high    male     face  pain         0 -2.242  female
#
#         race  frontal_N1  ...   FC4_N2    C3_N2    C1_N2     Cz_N2    C2_N2  \
# ...

# %%
m_reg_new = hddm.HDDMRegressor(data,
                           "a ~ Cz_P2",
                           depends_on={'v': 'race'})
m_reg_new.sample(20000, burn=1000, dbname='db_Cz_P2', db='pickle')
m_reg_new.save('model_Cz_P2')
# Out:
# Adding these covariates:
# ['a_Intercept', 'a_Cz_P2']
#  [-----------------76%---------         ] 15371 of 20000 complete in 6149.0 sec
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
a_Cz_P2 = m_reg_new.nodes_db.node["a_Cz_P2"]

# %%
hddm.analyze.plot_posterior_nodes([a_Cz_P2], bins=20)
plt.xlabel('a_Cz_P2 coeffecient in ')
print("P( > 0) = ", (a_Cz_P2.trace() < 0).mean())
# Out:
# P( > 0) =  0.015894736842105264
